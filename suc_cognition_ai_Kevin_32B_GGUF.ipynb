# %%
curl -fsSL https://ollama.com/install.sh | sh
nohup ollama serve &
ollama pull llama3:8b
ollama list

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !ollama run hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_S
# Out:
# pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 62b5b3dde6eb:   0% ▕▏ 2.3 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   0% ▕▏  15 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   1% ▕▏  58 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   1% ▕▏  76 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   1% ▕▏ 117 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   1% ▕▏ 152 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   2% ▕▏ 185 MB/ 10 GB                  pulling manifest
# pulling 62b5b3dde6eb:   2% ▕▏ 209 MB/ 10 GB                  pulling manifest
# ...

# %%
# !ollama list
# Out:
# NAME                                                 ID              SIZE     MODIFIED
# hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_S    0048855af7ad    10 GB    2 minutes ago

# %%
# !ollama run hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_S
# Out:
# Error: model requires more system memory (12.4 GiB) than is available (11.6 GiB)

# %%
# !ollama rm hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_S
# Out:
# deleted 'hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_S'

# %%
# !ollama run hf.co/bartowski/cognition-ai_Kevin-32B-GGUF:IQ2_XXS
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling 2611e4985d2d:   0% ▕▏ 1.2 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   0% ▕▏ 9.6 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   0% ▕▏  17 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   0% ▕▏  28 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   0% ▕▏  44 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   1% ▕▏  52 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   1% ▕▏  69 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   1% ▕▏  90 MB/9.0 GB                  pulling manifest
# pulling 2611e4985d2d:   1% ▕▏ 100 MB/9.0 GB                  pulling manifest
# ...
